# %%
print("SOLVED EXAMPLE:")
print("Create a complex number and find its conjugate")
z = 3 + 4j
conjugate = z.conjugate()
magnitude = abs(z)
print("Complex number:", z)
print("Conjugate:", conjugate)
print("Magnitude:", magnitude)
print("-" * 50)

print("Question 1")
z1 = 5 + 3j
print(z1)

print("\nQuestion 2")
z2 = 7 - 2j
print(z2.real)

print("\nQuestion 3")
z3 = 4 + 6j
print(z3.imag)

print("\nQuestion 4")
print((3 + 2j) + (1 + 4j))

print("\nQuestion 5")
print((2 + 3j) * (1 + 2j))

print("\nQuestion 6")
print(abs(6 + 8j))

print("\nQuestion 7")
print((5 - 7j).conjugate())

print("\nQuestion 8")
print((10 + 5j) - (3 + 2j))

print("\nQuestion 9")
print((8 + 6j) / (2 + 1j))

print("\nQuestion 10")
z10 = 1 + 1j
print(math.atan2(z10.imag, z10.real))
