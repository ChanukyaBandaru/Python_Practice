# %%
print("SOLVED EXAMPLE:")
print("Check if a number is both even and greater than 10")
number = 16
is_even = number % 2 == 0
is_greater_than_10 = number > 10
result = is_even and is_greater_than_10
print("Number:", number)
print("Is even:", is_even)
print("Is greater than 10:", is_greater_than_10)
print("Both conditions:", result)
print("-" * 50)

print("Question 1")
print(25 > 20 and 25 < 30)

print("\nQuestion 2")
print("python" == "Python")

print("\nQuestion 3")
print(15 % 3 == 0 and 15 % 5 == 0)

print("\nQuestion 4")
print(7 != 8)

print("\nQuestion 5")
print(100 > 50 or 100 < 25)

print("\nQuestion 6")
print(bool(0))

print("\nQuestion 7")
print(bool(""))

print("\nQuestion 8")
print(bool(42))

print("\nQuestion 9")
print(5 <= 10 <= 15)

print("\nQuestion 10")
print(3.14 > 3 and 3.14 < 4)
