# %%
print("SOLVED EXAMPLE:")
print("Check if a variable is None")
variable = None
is_none = variable is None
print("Variable:", variable)
print("Is None:", is_none)
print("-" * 50)

print("Question 1")
x = None
print(x)

print("\nQuestion 2")
print(None == None)

print("\nQuestion 3")
print(None is None)

print("\nQuestion 4")
print(0 is None)

print("\nQuestion 5")
print("" is None)

print("\nQuestion 6")
print(False is None)

print("\nQuestion 7")
print([] is None)

print("\nQuestion 8")
print({} is None)

print("\nQuestion 9")
print(() is None)

print("\nQuestion 10")
print(set() is None)
