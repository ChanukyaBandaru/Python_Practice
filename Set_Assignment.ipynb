# %%
print("SOLVED EXAMPLE:")
print("Find the union of two sets")
set1 = {1, 2, 3, 4, 5}
set2 = {4, 5, 6, 7, 8}
union_set = set1.union(set2)
print("Set 1:", set1)
print("Set 2:", set2)
print("Union:", union_set)
print("-" * 50)

print("Question 1")
s1 = set(range(1, 11))
print(s1)

print("\nQuestion 2")
s2 = {1, 2, 3, 4, 5}
s2.add(11)
print(s2)

print("\nQuestion 3")
s3 = {1, 2, 3, 4, 5, 6}
s3.remove(3)
print(s3)

print("\nQuestion 4")
a = {1, 2, 3, 4, 5}
b = {4, 5, 6, 7, 8}
print(a & b)

print("\nQuestion 5")
print(a - b)

print("\nQuestion 6")
s4 = {1, 2, 3, 4, 6, 7, 8}
print(5 in s4)

print("\nQuestion 7")
s5 = {'a', 'b', 'c', 'd', 'e'}
print(len(s5))

print("\nQuestion 8")
text = "hello world"
vowels = {'a','e','i','o','u'}
print(set(ch for ch in text if ch in vowels))

print("\nQuestion 9")
lst = [1,2,2,3,4,4,5,6,6,7]
print(list(set(lst)))

print("\nQuestion 10")
print({1,2,3}.issubset({1,2,3,4,5,6}))
