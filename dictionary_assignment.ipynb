# %%
print("SOLVED EXAMPLE:")
scores = {'Alice': 85, 'Bob': 92, 'Charlie': 78, 'Diana': 95, 'Eve': 88}
max_key = max(scores, key=scores.get)
print("Dictionary:", scores)
print("Key with maximum value:", max_key)
print("Maximum value:", scores[max_key])
print("-" * 50)

print("Question 1")
students = {'Alice': 20, 'Bob': 21, 'Charlie': 22}
print(students)

print("\nQuestion 2")
d = {'a':1,'b':2,'c':3}
d['d'] = 4
print(d)

print("\nQuestion 3")
d = {'name':'John','age':25,'city':'New York'}
print(list(d.keys()))

print("\nQuestion 4")
d = {'python':3,'java':2,'c++':1}
print(list(d.values()))

print("\nQuestion 5")
d = {'name':'Alice','age':30,'city':'London'}
print('age' in d)

print("\nQuestion 6")
d = {'a':1,'b':2,'temp':3,'c':4}
d.pop('temp')
print(d)

print("\nQuestion 7")
marks = {'math':85,'science':92,'english':78}
print(sum(marks.values()))

print("\nQuestion 8")
print({i:i*i for i in range(1,6)})

print("\nQuestion 9")
s = "hello"
freq = {}
for ch in s:
    freq[ch] = freq.get(ch,0)+1
print(freq)

print("\nQuestion 10")
d1 = {'a':1,'b':2}
d2 = {'c':3,'d':4}
print({**d1, **d2})

print("\nQuestion 11")
nested = {'person':{'name':'Alice','age':25}}
print(nested)

print("\nQuestion 12")
print(nested['person']['name'])

print("\nQuestion 13")
d = {'fruits':['apple','banana'],'colors':['red','blue']}
print(d)

print("\nQuestion 14")
d['fruits'].append('orange')
print(d)

print("\nQuestion 15")
d = {'coordinates':(10,20),'rgb':(255,0,0)}
print(d)

print("\nQuestion 16")
print(d['coordinates'][0])

print("\nQuestion 17")
d = {'vowels':{'a','e','i'},'consonants':{'b','c','d'}}
print(d)

print("\nQuestion 18")
d['vowels'].add('o')
print(d)

print("\nQuestion 19")
company = {'company':{'department':{'employee':{'name':'John','id':123}}}}
print(company)

print("\nQuestion 20")
print(company['company']['department']['employee']['name'])

print("\nQuestion 21")
mixed = {'int':42,'float':3.14,'str':'hello','bool':True}
print(mixed)

print("\nQuestion 22")
print({k:type(v) for k,v in mixed.items()})

print("\nQuestion 23")
funcs = {'len':len,'str':str,'int':int}
print(funcs)

print("\nQuestion 24")
print({k:f("123") for k,f in funcs.items()})

print("\nQuestion 25")
lambdas = {'double':lambda x:x*2,'square':lambda x:x**2}
print(lambdas)

print("\nQuestion 26")
print({k:f(5) for k,f in lambdas.items()})

print("\nQuestion 27")
classes = {'list':list,'dict':dict,'set':set}
print(classes)

print("\nQuestion 28")
print({k:v() for k,v in classes.items()})

print("\nQuestion 29")
d = {'a':None,'b':None,'c':None}
print(d)

print("\nQuestion 30")
print({k:0 if v is None else v for k,v in d.items()})

print("\nQuestion 31")
bools = {'is_active':True,'is_admin':False}
print(bools)

print("\nQuestion 32")
print(sum(bools.values()))

print("\nQuestion 33")
complex_d = {'z1':3+4j,'z2':1+2j}
print(complex_d)

print("\nQuestion 34")
print({k:abs(v) for k,v in complex_d.items()})

print("\nQuestion 35")
deep = {'a':{'b':{'c':{'d':100}}}}
print(deep)

print("\nQuestion 36")
print(deep['a']['b']['c']['d'])

print("\nQuestion 37")
ranges = {'r1':range(3),'r2':range(5)}
print(ranges)

print("\nQuestion 38")
print({k:list(v) for k,v in ranges.items()})

print("\nQuestion 39")
gens = {'g1':(x for x in range(3)),'g2':(x for x in range(5))}
print(gens)

print("\nQuestion 40")
print({k:list(v) for k,v in gens.items()})

print("\nQuestion 41")
iters = {'i1':iter([1,2,3]),'i2':iter([4,5,6])}
print(iters)

print("\nQuestion 42")
print({k:list(v) for k,v in iters.items()})

print("\nQuestion 43")
d = {'matrix':[[1,2],[3,4]],'vector':[5,6,7]}
print(d)

print("\nQuestion 44")
print({k:sum(v) if isinstance(v,list) else None for k,v in d.items()})

print("\nQuestion 45")
config = {'config':{'db':{'host':'localhost','port':5432}}}
print(config)

print("\nQuestion 46")
print(config['config']['db']['port'])

print("\nQuestion 47")
d = {'points':((1,2),(3,4)),'rgb':((255,0,0),(0,255,0))}
print(d)

print("\nQuestion 48")
print(d['points'][0])

print("\nQuestion 49")
d = {'groups':[ {1,2,3},{4,5,6} ], 'categories':[ {'a','b'},{'c','d'} ]}
print(d)

print("\nQuestion 50")
print(set().union(*d['groups'], *d['categories']))
